# %%
# coding:utf-8

import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split


# %matplotlib inline

# %%
train_user = pd.read_csv('data/table1_user',encoding='utf-8',index_col = False, delimiter='\t',
                                 )
train_user['cur_jd_type'] = train_user['cur_jd_type'].astype(str)
train_user.loc[train_user['cur_jd_type']=='nan',['cur_jd_type']] = '无业'
train_job = pd.read_csv("data/table2_jd",delimiter="\t",error_bad_lines=False)
train_action = pd.read_csv("data/table3_action",delimiter="\t")
test_action = pd.read_csv("data/zhaopin_round1_user_exposure_A_20190723",delim_whitespace=True)
test_user = pd.read_csv("data/user_ToBePredicted",delimiter="\t")
test_user['cur_jd_type'] = test_user['cur_jd_type'].astype(str)
test_user.loc[test_user['cur_jd_type']=='nan',['cur_jd_type']] = '无业'
train_action['mix_sat']  = train_action['satisfied']*10+train_action['delivered']*3
train_action.loc[train_action.mix_sat==13,'mix_sat'] =10
# Out:
# b'Skipping line 173315: expected 18 fields, saw 20\n'
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train_big_table = pd.merge(train_action,train_user,how="inner",on="user_id")
train_big_table = pd.merge(train_big_table,train_job,how="left",on="jd_no")
test_big_table = pd.merge(test_action,test_user,how="inner",on="user_id")
test_big_table = pd.merge(test_big_table,train_job,how="left",on="jd_no")
train_big_table.drop_duplicates(inplace=True)
test_big_table.drop_duplicates(inplace=True)

# %%
train_big_table['jd_sub_type'] = train_big_table['jd_sub_type'].astype(str)
train_big_table.loc[train_big_table['jd_sub_type']=='nan',['jd_sub_type']] = '未给出'
test_big_table['jd_sub_type'] = test_big_table['jd_sub_type'].astype(str)
test_big_table.loc[test_big_table['jd_sub_type']=='nan',['jd_sub_type']] = '未给出'

# %%
jd_sub_action_series = train_big_table.groupby(['jd_sub_type'])['browsed'].count()
jd_sub_action =pd.DataFrame({'jd_sub_type':jd_sub_action_series.index, 'jd_sub_pos_cont':jd_sub_action_series.values})
jd_sub_action['jd_sub_browsed_rate'] = train_big_table.groupby(['jd_sub_type'])['browsed'].mean().values
jd_sub_action['jd_sub_delivered_rate'] = train_big_table.groupby(['jd_sub_type'])['delivered'].mean().values
jd_sub_action['jd_sub_satisfied_rate'] = train_big_table.groupby(['jd_sub_type'])['satisfied'].mean().values
train_big_table = pd.merge(train_big_table,jd_sub_action,how="left",on="jd_sub_type")
test_big_table = pd.merge(test_big_table,jd_sub_action,how="left",on="jd_sub_type")

# %%
test_big_table.loc[test_big_table['jd_sub_type']=='办事处首席代表',['jd_sub_pos_cont','jd_sub_browsed_rate','jd_sub_delivered_rate','jd_sub_satisfied_rate']] = 460,0.295652,0.134783,0.036957
test_big_table.loc[test_big_table['jd_sub_type']=='装订工',['jd_sub_pos_cont','jd_sub_browsed_rate','jd_sub_delivered_rate','jd_sub_satisfied_rate']] = 9,0.333333,0.000000,0.000000
test_big_table.loc[test_big_table['jd_sub_type']=='拍卖师',['jd_sub_pos_cont','jd_sub_browsed_rate','jd_sub_delivered_rate','jd_sub_satisfied_rate']] = 169,0.218935,0.094675,0.03550
test_big_table[test_big_table['jd_sub_pos_cont'].isnull()]
# Out:
# Empty DataFrame
# Columns: [user_id, jd_no, live_city_id, desire_jd_city_id, desire_jd_industry_id, desire_jd_type_id, desire_jd_salary_id, cur_industry_id, cur_jd_type, cur_salary_id, cur_degree_id, birthday, start_work_date, experience, jd_title, company_name, city, jd_sub_type, require_nums, max_salary, min_salary, start_date, end_date, is_travel, min_years, key, min_edu_level, max_edu_level, is_mangerial, resume_language_required, job_description, jd_sub_pos_cont, jd_sub_browsed_rate, jd_sub_delivered_rate, jd_sub_satisfied_rate]
# Index: []
#
# [0 rows x 35 columns]

# %%
cur_jd_action_series = train_big_table.groupby(['cur_jd_type'])['browsed'].count()
cur_jd_action =pd.DataFrame({'cur_jd_type':cur_jd_action_series.index, 'cur_jd_pos_cont':cur_jd_action_series.values})
cur_jd_action['cur_jd_browsed_rate'] = train_big_table.groupby(['cur_jd_type'])['browsed'].mean().values
cur_jd_action['cur_jd_delivered_rate'] = train_big_table.groupby(['cur_jd_type'])['delivered'].mean().values
cur_jd_action['cur_jd_satisfied_rate'] = train_big_table.groupby(['cur_jd_type'])['satisfied'].mean().values
test_big_table = pd.merge(test_big_table,cur_jd_action,how="left",on="cur_jd_type")
train_big_table = pd.merge(train_big_table,cur_jd_action,how="left",on="cur_jd_type")

# %%
test_big_table.loc[test_big_table['cur_jd_type']=='人力资源经理',['cur_jd_pos_cont','cur_jd_browsed_rate','cur_jd_delivered_rate','cur_jd_satisfied_rate']] = 20275,0.276893,0.131591,0.051837
test_big_table.loc[test_big_table['cur_jd_type']=='市场策划/企划经理/主管',['cur_jd_pos_cont','cur_jd_browsed_rate','cur_jd_delivered_rate','cur_jd_satisfied_rate']] = 424,0.261792,0.143868,0.051887
test_big_table[test_big_table['cur_jd_pos_cont'].isnull()]
# Out:
# Empty DataFrame
# Columns: [user_id, jd_no, live_city_id, desire_jd_city_id, desire_jd_industry_id, desire_jd_type_id, desire_jd_salary_id, cur_industry_id, cur_jd_type, cur_salary_id, cur_degree_id, birthday, start_work_date, experience, jd_title, company_name, city, jd_sub_type, require_nums, max_salary, min_salary, start_date, end_date, is_travel, min_years, key, min_edu_level, max_edu_level, is_mangerial, resume_language_required, job_description, jd_sub_pos_cont, jd_sub_browsed_rate, jd_sub_delivered_rate, jd_sub_satisfied_rate, cur_jd_pos_cont, cur_jd_browsed_rate, cur_jd_delivered_rate, cur_jd_satisfied_rate]
# Index: []
#
# [0 rows x 39 columns]

# %%
train_big_table['start_date'].fillna('na',inplace=True)
test_big_table['start_date'].fillna('na',inplace=True)
train_big_table['end_date'].fillna('na',inplace=True)
test_big_table['end_date'].fillna('na',inplace=True)

# %%
train_big_table['start_date'] = train_big_table['start_date'].astype(str)
train_big_table['end_date'] = train_big_table['end_date'].astype(str)
test_big_table['start_date'] = test_big_table['start_date'].astype(str)
test_big_table['end_date'] = test_big_table['end_date'].astype(str)

# %%
from datetime import datetime

def remain_date(x):
    if  'N' in x :
        return 99999;
    elif 'na' in x:
        return -1
    else:
        d1 = datetime.strptime('20190327', "%Y%m%d")
        d2 = datetime.strptime(x, "%Y%m%d")
        return abs((d2 - d1).days)
    
train_big_table['remain_date'] = train_big_table['end_date'].apply(remain_date)
test_big_table['remain_date'] = test_big_table['end_date'].apply(remain_date)

# %%
def month_convert(x):
    if  'N' in x:
        return -1;
    elif 'na' in x:
        return -1
    else:
        if int(x[0:6])< 201804:
            return '201804'
        else:
            return x[0:6]

train_big_table['start_month'] = train_big_table['start_date'].apply(month_convert)
test_big_table['start_month'] = test_big_table['start_date'].apply(month_convert)

# %%
def extract_city(citys,index):
    city_list = citys.split(",")
    if index < len(city_list):
        city = city_list[index]
        if city != "-":
            city = int(city)
        else:
            city = -1
    else:
        city = -1
    return city

def exp_in_desc(exp,desc):
    if str(exp) == "nan":
        exp = ""
    exps = exp.split("|")
    num = 0
    for item in exps:
        if item in desc:
            num+=1
    return num

# %%
min_year_dict = {
    305: 4,
    -1:-1,
    1:1,
    103:2,
    0:0,
    510:7,
    1099:10,
    399:4,
    599:7,
    199:1,
    299:2,
    110:1
}
degree_dict = {
    "初中":1,
    "中技":2,
    "高中":3,
    "中专":3,
    "大专":4,
    "本科":5,
    "硕士":6,
    "博士":7,
    "EMBA":7,
    "MBA":6,
    "其他":0,
    "请选择":0,
    "\\N":0,
    "na":0
}
min_salary_dict = {
    100002000:1000,
    400106000:4001,
    0:0,
    200104000:2001,
    600108000:6001,
    800110000:8001,
    1000115000:10001,
    2500199999:25001,
    1500125000:15001,
    3500150000:35001,
    70001100000:70001,
    1000:0,
    100001150000:100001,
    2500135000:25001,
    5000170000:50001
}
max_salary_dict = {
    100002000:2000,
    400106000:6000,
    0:0,
    200104000:4000,
    600108000:8000,
    800110000:10000,
    1000115000:15000,
    2500199999:99999,
    1500125000:25000,
    3500150000:50000,
    70001100000:100000,
    1000:1000,
    100001150000:150000,
    2500135000:35000,
    5000170000:70000
}

# %%
train_big_table['min_years'].fillna(-1,inplace=True)
test_big_table['min_years'].fillna(-1,inplace=True)
train_big_table['cur_degree_id'].fillna('na',inplace=True)
test_big_table['cur_degree_id'].fillna('na',inplace=True)
train_big_table['desire_jd_salary_id'].fillna(0,inplace=True)
test_big_table['desire_jd_salary_id'].fillna(0,inplace=True)
train_big_table['job_description'].fillna("",inplace=True)
test_big_table['job_description'].fillna("",inplace=True)

# %%
from functools import partial
def fe(df):
    df["desire_jd_city_1"] = df["desire_jd_city_id"].apply(partial(extract_city,index=0))
    df["desire_jd_city_2"] = df["desire_jd_city_id"].apply(partial(extract_city,index=1))
    df["desire_jd_city_3"] = df["desire_jd_city_id"].apply(partial(extract_city,index=2))
    df["desire_jd_city_num"] = df[["desire_jd_city_1","desire_jd_city_2","desire_jd_city_3"]].sum(axis=1)
    
    df["city_equal_desired_city_1"] = df["desire_jd_city_1"]==df["city"]
    df["city_equal_desired_city_2"] = df["desire_jd_city_2"]==df["city"]
    df["city_equal_desired_city_3"] = df["desire_jd_city_3"]==df["city"]
    
    df["work_years"] = 2019-df["start_work_date"].apply(lambda x : 2018 if x=="-" else int(x))
    
    
    df["desire_min_salary"] = df["desire_jd_salary_id"].apply(lambda x: min_salary_dict[x])
    df["desire_max_salary"] = df["desire_jd_salary_id"].apply(lambda x: max_salary_dict[x])
    df["desire_salary_diff"] = df["desire_max_salary"]-df["desire_min_salary"]
    
    df["min_years"] = df["min_years"].apply(lambda x: min_year_dict[x])
    
    df["work_years_statisfied"] = df["work_years"].astype(int) > df["min_years"]
    
    df["salary_large_than_desire"] = df["desire_min_salary"] > df["min_salary"]
    
    df["cur_salary_min"] = df["cur_salary_id"].apply(lambda x: min_salary_dict[int(x if str.isnumeric(x) else "0")])
    df["cur_salary_max"] = df["cur_salary_id"].apply(lambda x: max_salary_dict[int(x if str.isnumeric(x) else "0")])
    
    df["salary_large_than_cur"] = df["cur_salary_min"] > df["min_salary"]
    
    df["cur_degree_id"] = df["cur_degree_id"].fillna("na").apply(lambda x:degree_dict[x.strip()])
    
    df["job_description_len"] = df["job_description"].apply(len)
    
    df["experience_num"] = df["experience"].apply(lambda x: len(str(x).split("|")) if str(x) != "nan" else 0)
    
    df["min_edu_level"] = df["min_edu_level"].fillna("na").apply(lambda x:degree_dict[x.strip()])
    exp_in_desc_num = []
    for idx, data in df.iterrows():
        exp_in_desc_num.append(exp_in_desc(data["experience"],data["job_description"]))
    df["exp_in_desc_num"] = exp_in_desc_num
    
#     "live_city_id","desire_jd_salary_id","cur_industry_id","cur_jd_type","cur_salary_id",
#          "cur_degree_id","city","jd_sub_type",
#          "max_salary","min_salary","is_travel","min_years","min_edu_level",
#          "desire_jd_city_1","desire_jd_city_2","desire_jd_city_3","work_years_statisfied"
    cross_feature_tuple = [("live_city_id","city"),("live_city_id","desire_jd_city_1"),("cur_industry_id","jd_sub_type"),
                          ("cur_jd_type","jd_sub_type"),("cur_salary_id","cur_degree_id"),("city","jd_sub_type"),
                          ("jd_sub_type","min_salary"),("jd_sub_type","max_salary"),("jd_sub_type","is_travel"),
                          ("min_years","jd_sub_type"),("jd_sub_type","require_nums"),
                          
                          
                          
                          ]
    cross_feature_names = list(feature[0]+"&"+feature[1] for feature in cross_feature_tuple)
    print("create cross features",cross_feature_names)
    for idx,(fa,fb) in enumerate(cross_feature_tuple):
        df[cross_feature_names[idx]] = df[fa].astype(str)+df[fb].astype(str)
    return cross_feature_names

# %%
cross_feature_names = fe(train_big_table)
fe(test_big_table)
# Out:
# create cross features ['live_city_id&city', 'live_city_id&desire_jd_city_1', 'cur_industry_id&jd_sub_type', 'cur_jd_type&jd_sub_type', 'cur_salary_id&cur_degree_id', 'city&jd_sub_type', 'jd_sub_type&min_salary', 'jd_sub_type&max_salary', 'jd_sub_type&is_travel', 'min_years&jd_sub_type', 'jd_sub_type&require_nums']
# create cross features ['live_city_id&city', 'live_city_id&desire_jd_city_1', 'cur_industry_id&jd_sub_type', 'cur_jd_type&jd_sub_type', 'cur_salary_id&cur_degree_id', 'city&jd_sub_type', 'jd_sub_type&min_salary', 'jd_sub_type&max_salary', 'jd_sub_type&is_travel', 'min_years&jd_sub_type', 'jd_sub_type&require_nums']
# ['live_city_id&city',
#  'live_city_id&desire_jd_city_1',
#  'cur_industry_id&jd_sub_type',
#  'cur_jd_type&jd_sub_type',
#  'cur_salary_id&cur_degree_id',
#  'city&jd_sub_type',
#  'jd_sub_type&min_salary',
#  'jd_sub_type&max_salary',
#  'jd_sub_type&is_travel',
#  'min_years&jd_sub_type',
#  'jd_sub_type&require_nums']

# %%
train_big_table['require_nums'].value_counts()
# Out:
# 1.0      238923
# 2.0       81291
# 3.0       56091
# 5.0       44041
# 10.0      26808
# 4.0       13744
# 6.0        8923
# 20.0       7815
# 999.0      6153
# 8.0        4461
# 15.0       3946
# 30.0       3494
# 50.0       2109
# 100.0      1258
# 7.0        1079
# 12.0        850
# 99.0        445
# 9.0         442
# 18.0        363
# 200.0       319
# 40.0        309
# 11.0        305
# 25.0        287
# 60.0        230
# 16.0        226
# 896.0       221
# 500.0       184
# 13.0        178
# 35.0        155
# 19.0        141
#           ...
# 104.0         3
# 499.0         3
# 125.0         3
# 56.0          3
# 166.0         3
# 41.0          2
# 140.0         2
# 67.0          2
# 79.0          2
# 34.0          2
# 37.0          2
# 133.0         2
# 93.0          2
# 378.0         2
# 148.0         2
# 400.0         2
# 88.0          1
# 68.0          1
# 77.0          1
# 101.0         1
# 115.0         1
# 122.0         1
# 38.0          1
# 220.0         1
# 211.0         1
# 86.0          1
# 128.0         1
# 47.0          1
# 84.0          1
# 290.0         1
# Name: require_nums, Length: 110, dtype: int64

# %%
#

# %%
all_big_table = pd.concat([train_big_table,test_big_table])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if __name__ == '__main__':

# %%
from sklearn.preprocessing import LabelEncoder
from tqdm import tqdm as tqdm
import lightgbm as lgb

# %%
def feature_select(target,*df_list):
    result = []
    cat_features = ["live_city_id","desire_jd_salary_id","cur_industry_id","cur_jd_type","cur_salary_id",
         "cur_degree_id","city","jd_sub_type","start_month",
         "max_salary","min_salary","is_travel","min_years","min_edu_level",
         "desire_jd_city_1","desire_jd_city_2","desire_jd_city_3","work_years_statisfied"]+cross_feature_names
    lbl_dict = {}
    for f in cat_features:
        lbl = LabelEncoder()
        lbl.fit(all_big_table[f].astype(str))
        lbl_dict[f] = lbl
    for df in df_list:
        features = ["live_city_id","desire_jd_salary_id","cur_industry_id","cur_jd_type","cur_salary_id",
             "cur_degree_id","birthday","city","jd_sub_type","require_nums",
                    "jd_sub_pos_cont","jd_sub_browsed_rate",
                    "jd_sub_delivered_rate","jd_sub_satisfied_rate",
                    "start_month",
             "max_salary","min_salary","is_travel","min_years","min_edu_level",
             "desire_jd_city_1","desire_jd_city_2","desire_jd_city_3","exp_in_desc_num",
                   "city_equal_desired_city_1","city_equal_desired_city_2","city_equal_desired_city_3",
                   "desire_min_salary","desire_max_salary","salary_large_than_desire","cur_salary_min",
                   "cur_salary_max","salary_large_than_cur","job_description_len","experience_num","work_years_statisfied","work_years","desire_jd_city_num","desire_salary_diff"]+cross_feature_names

        x = df[features]
        if target in df.columns:
            y = df[target]
        else:
            y = None
        for f in cat_features:
            lbl = lbl_dict[f]
            x[f] = lbl.transform(x[f].astype(str))
        result.append((x,y))
    return result

# %%
from sklearn.model_selection import KFold

def cross_validate(param=dict(n_estimators=1000,metric="map",colsample_bytree=0.2,max_depth=7,importance_type="gain")
                   ,n_folds=5,target="mix_sat"):
    train_users = train_big_table["user_id"].unique()
    folds = KFold(n_folds,shuffle=True,random_state=42)
    models = []
    test_pred = np.zeros(test_big_table.shape[0])
    scores = []
    for idx,(train_idx,valid_idx) in enumerate(folds.split(train_users)):
        t_user = train_users[train_idx]
        v_user = train_users[valid_idx]
        train_data = train_big_table[train_big_table["user_id"].isin(t_user)]
        valid_data = train_big_table[train_big_table["user_id"].isin(v_user)]
        train_group = train_data.groupby("user_id",as_index=False).count()["mix_sat"].values
        valid_group = valid_data.groupby("user_id",as_index=False).count()["mix_sat"].values
        test_group = test_big_table.groupby("user_id",as_index=False).count()["jd_no"].values
        
        result = feature_select(target,train_data,valid_data,test_big_table)
        t_x,t_y = result[0]
        v_x,v_y = result[1]
        test_x,_ = result[2]
        model = lgb.LGBMRanker(**param)
        print("Fold",idx,"-"*30)
        model.fit(t_x,t_y,group=train_group,eval_set=[(t_x,t_y),(v_x,v_y)],eval_group=[train_group,valid_group],early_stopping_rounds=100,verbose=10,
                  callbacks=[lgb.reset_parameter(learning_rate=lambda x: 0.03)]
                 )
        models.append(model)
        test_pred += model.predict(test_x)/n_folds
        scores.append(model.best_score_["valid_1"]["map@1"])
    print("mean score",np.mean(scores))
    return models,test_pred

# %%
train_big_table.head()
# Out:
#                             user_id                             jd_no  \
# 0  17e1b9f107dd1214bd78dec6d91593a4  4ce99de185f55bea127ccd74c4bbf0ad
# 1  17e1b9f107dd1214bd78dec6d91593a4  e9959d3b5fd8b26da07e8b8a3b80489a
# 2  17e1b9f107dd1214bd78dec6d91593a4  7ecd6ab0c7e43b40b7d1dbd4a9b1e6f5
# 3  17e1b9f107dd1214bd78dec6d91593a4  112ea9c8ef92c1a7d5fa679cc6c05053
# 4  17e1b9f107dd1214bd78dec6d91593a4  1953082bf7ee0919820eb7ba05be3425
#
#    browsed  delivered  satisfied  mix_sat  live_city_id desire_jd_city_id  \
# 0        0          0          0        0           551           551,-,-
# 1        0          0          0        0           551           551,-,-
# 2        0          0          0        0           551           551,-,-
# 3        0          0          0        0           551           551,-,-
# 4        0          0          0        0           551           551,-,-
#
#   desire_jd_industry_id desire_jd_type_id  ...  live_city_id&desire_jd_city_1  \
# 0          房地产/建筑/建材/工程          工程造价/预结算  ...                         551551
# 1          房地产/建筑/建材/工程          工程造价/预结算  ...                         551551
# 2          房地产/建筑/建材/工程          工程造价/预结算  ...                         551551
# 3          房地产/建筑/建材/工程          工程造价/预结算  ...                         551551
# 4          房地产/建筑/建材/工程          工程造价/预结算  ...                         551551
#
#   cur_industry_id&jd_sub_type cur_jd_type&jd_sub_type  \
# 0        房地产/建筑/建材/工程工程造价/预结算   土木/建筑/装修/市政工程工程造价/预结算
# 1           房地产/建筑/建材/工程项目招投标      土木/建筑/装修/市政工程项目招投标
# 2        房地产/建筑/建材/工程工程造价/预结算   土木/建筑/装修/市政工程工程造价/预结算
# 3        房地产/建筑/建材/工程工程造价/预结算   土木/建筑/装修/市政工程工程造价/预结算
# 4        房地产/建筑/建材/工程工程造价/预结算   土木/建筑/装修/市政工程工程造价/预结算
#
#   cur_salary_id&cur_degree_id  city&jd_sub_type  jd_sub_type&min_salary  \
# 0                 02001040004     551.0工程造价/预结算          工程造价/预结算4000.0
# 1                 02001040004        551.0项目招投标             项目招投标3000.0
# 2                 02001040004     551.0工程造价/预结算          工程造价/预结算2001.0
# 3                 02001040004     551.0工程造价/预结算          工程造价/预结算2001.0
# 4                 02001040004     551.0工程造价/预结算          工程造价/预结算4000.0
#
#   jd_sub_type&max_salary jd_sub_type&is_travel min_years&jd_sub_type  \
# 0         工程造价/预结算8000.0           工程造价/预结算1.0             4工程造价/预结算
# 1            项目招投标6000.0              项目招投标1.0               -1项目招投标
# 2         工程造价/预结算4000.0           工程造价/预结算0.0             1工程造价/预结算
# 3         工程造价/预结算4000.0           工程造价/预结算0.0             1工程造价/预结算
# 4         工程造价/预结算8000.0           工程造价/预结算0.0             2工程造价/预结算
#
#   jd_sub_type&require_nums
# 0              工程造价/预结算5.0
# 1                 项目招投标3.0
# 2              工程造价/预结算1.0
# 3              工程造价/预结算1.0
# 4              工程造价/预结算2.0
#
# [5 rows x 75 columns]

# %%
models,pred = cross_validate(target="mix_sat",param=dict(n_estimators=1000,metric="map",subsample=0.6,min_split_gain=10,colsample_bytree=0.6,max_depth=7,importance_type="gain"),n_folds=5)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Fold 0 ------------------------------
# Training until validation scores don't improve for 100 rounds.
# [10]	training's map@1: 0.260833	valid_1's map@1: 0.245556
# [20]	training's map@1: 0.271111	valid_1's map@1: 0.243333
# [30]	training's map@1: 0.276667	valid_1's map@1: 0.244444
# [40]	training's map@1: 0.279444	valid_1's map@1: 0.244444
# [50]	training's map@1: 0.287222	valid_1's map@1: 0.243333
# [60]	training's map@1: 0.289444	valid_1's map@1: 0.25
# [70]	training's map@1: 0.292778	valid_1's map@1: 0.252222
# [80]	training's map@1: 0.296667	valid_1's map@1: 0.254444
# [90]	training's map@1: 0.297778	valid_1's map@1: 0.247778
# [100]	training's map@1: 0.300556	valid_1's map@1: 0.253333
# [110]	training's map@1: 0.304167	valid_1's map@1: 0.246667
# [120]	training's map@1: 0.306667	valid_1's map@1: 0.248889
# [130]	training's map@1: 0.31	valid_1's map@1: 0.247778
# [140]	training's map@1: 0.310556	valid_1's map@1: 0.247778
# [150]	training's map@1: 0.310556	valid_1's map@1: 0.247778
# [160]	training's map@1: 0.313889	valid_1's map@1: 0.245556
# [170]	training's map@1: 0.318056	valid_1's map@1: 0.247778
# Early stopping, best iteration is:
# [72]	training's map@1: 0.293056	valid_1's map@1: 0.256667
# Fold 1 ------------------------------
# Training until validation scores don't improve for 100 rounds.
# [10]	training's map@1: 0.250833	valid_1's map@1: 0.238889
# [20]	training's map@1: 0.251944	valid_1's map@1: 0.244444
# [30]	training's map@1: 0.256944	valid_1's map@1: 0.247778
# [40]	training's map@1: 0.266944	valid_1's map@1: 0.252222
# [50]	training's map@1: 0.268056	valid_1's map@1: 0.247778
# [60]	training's map@1: 0.270556	valid_1's map@1: 0.246667
# [70]	training's map@1: 0.278611	valid_1's map@1: 0.245556
# [80]	training's map@1: 0.279444	valid_1's map@1: 0.247778
# [90]	training's map@1: 0.282778	valid_1's map@1: 0.243333
# [100]	training's map@1: 0.283889	valid_1's map@1: 0.244444
# [110]	training's map@1: 0.286389	valid_1's map@1: 0.244444
# [120]	training's map@1: 0.288889	valid_1's map@1: 0.246667
# [130]	training's map@1: 0.290278	valid_1's map@1: 0.247778
# [140]	training's map@1: 0.293333	valid_1's map@1: 0.247778
# Early stopping, best iteration is:
# [43]	training's map@1: 0.269167	valid_1's map@1: 0.255556
# Fold 2 ------------------------------
# Training until validation scores don't improve for 100 rounds.
# [10]	training's map@1: 0.252778	valid_1's map@1: 0.226667
# [20]	training's map@1: 0.261667	valid_1's map@1: 0.237778
# [30]	training's map@1: 0.2675	valid_1's map@1: 0.223333
# [40]	training's map@1: 0.269167	valid_1's map@1: 0.217778
# [50]	training's map@1: 0.271389	valid_1's map@1: 0.224444
# [60]	training's map@1: 0.277778	valid_1's map@1: 0.217778
# [70]	training's map@1: 0.280278	valid_1's map@1: 0.221111
# [80]	training's map@1: 0.283611	valid_1's map@1: 0.227778
# [90]	training's map@1: 0.285833	valid_1's map@1: 0.228889
# [100]	training's map@1: 0.288889	valid_1's map@1: 0.233333
# [110]	training's map@1: 0.291389	valid_1's map@1: 0.236667
# [120]	training's map@1: 0.292778	valid_1's map@1: 0.237778
# [130]	training's map@1: 0.297778	valid_1's map@1: 0.241111
# [140]	training's map@1: 0.299722	valid_1's map@1: 0.244444
# [150]	training's map@1: 0.299167	valid_1's map@1: 0.244444
# [160]	training's map@1: 0.303611	valid_1's map@1: 0.247778
# [170]	training's map@1: 0.306111	valid_1's map@1: 0.25
# [180]	training's map@1: 0.307222	valid_1's map@1: 0.251111
# [190]	training's map@1: 0.311111	valid_1's map@1: 0.247778
# [200]	training's map@1: 0.314167	valid_1's map@1: 0.247778
# [210]	training's map@1: 0.318333	valid_1's map@1: 0.248889
# [220]	training's map@1: 0.322222	valid_1's map@1: 0.248889
# [230]	training's map@1: 0.323333	valid_1's map@1: 0.25
# [240]	training's map@1: 0.325556	valid_1's map@1: 0.247778
# [250]	training's map@1: 0.327222	valid_1's map@1: 0.245556
# [260]	training's map@1: 0.331389	valid_1's map@1: 0.248889
# [270]	training's map@1: 0.333333	valid_1's map@1: 0.244444
# Early stopping, best iteration is:
# [175]	training's map@1: 0.306389	valid_1's map@1: 0.252222
# Fold 3 ------------------------------
# Training until validation scores don't improve for 100 rounds.
# [10]	training's map@1: 0.256389	valid_1's map@1: 0.25
# [20]	training's map@1: 0.2625	valid_1's map@1: 0.247778
# [30]	training's map@1: 0.265556	valid_1's map@1: 0.248889
# [40]	training's map@1: 0.269722	valid_1's map@1: 0.25
# [50]	training's map@1: 0.275833	valid_1's map@1: 0.255556
# [60]	training's map@1: 0.280278	valid_1's map@1: 0.256667
# [70]	training's map@1: 0.281389	valid_1's map@1: 0.26
# [80]	training's map@1: 0.288611	valid_1's map@1: 0.256667
# [90]	training's map@1: 0.291667	valid_1's map@1: 0.254444
# [100]	training's map@1: 0.295	valid_1's map@1: 0.257778
# [110]	training's map@1: 0.297778	valid_1's map@1: 0.263333
# [120]	training's map@1: 0.298889	valid_1's map@1: 0.26
# [130]	training's map@1: 0.300556	valid_1's map@1: 0.266667
# [140]	training's map@1: 0.301389	valid_1's map@1: 0.266667
# [150]	training's map@1: 0.3075	valid_1's map@1: 0.266667
# [160]	training's map@1: 0.308056	valid_1's map@1: 0.268889
# [170]	training's map@1: 0.31	valid_1's map@1: 0.267778
# [180]	training's map@1: 0.312222	valid_1's map@1: 0.267778
# [190]	training's map@1: 0.316667	valid_1's map@1: 0.268889
# [200]	training's map@1: 0.317778	valid_1's map@1: 0.267778
# [210]	training's map@1: 0.321389	valid_1's map@1: 0.264444
# [220]	training's map@1: 0.323056	valid_1's map@1: 0.265556
# [230]	training's map@1: 0.324167	valid_1's map@1: 0.267778
# [240]	training's map@1: 0.3275	valid_1's map@1: 0.27
# [250]	training's map@1: 0.329444	valid_1's map@1: 0.272222
# [260]	training's map@1: 0.331111	valid_1's map@1: 0.266667
# [270]	training's map@1: 0.333889	valid_1's map@1: 0.268889
# [280]	training's map@1: 0.336667	valid_1's map@1: 0.271111
# [290]	training's map@1: 0.342778	valid_1's map@1: 0.27
# [300]	training's map@1: 0.345278	valid_1's map@1: 0.271111
# [310]	training's map@1: 0.3475	valid_1's map@1: 0.273333
# [320]	training's map@1: 0.35	valid_1's map@1: 0.276667
# [330]	training's map@1: 0.350833	valid_1's map@1: 0.274444
# [340]	training's map@1: 0.352778	valid_1's map@1: 0.275556
# [350]	training's map@1: 0.355556	valid_1's map@1: 0.278889
# [360]	training's map@1: 0.355833	valid_1's map@1: 0.278889
# [370]	training's map@1: 0.358889	valid_1's map@1: 0.28
# [380]	training's map@1: 0.360278	valid_1's map@1: 0.277778
# [390]	training's map@1: 0.361944	valid_1's map@1: 0.277778
# [400]	training's map@1: 0.364167	valid_1's map@1: 0.277778
# [410]	training's map@1: 0.365278	valid_1's map@1: 0.277778
# [420]	training's map@1: 0.367222	valid_1's map@1: 0.276667
# [430]	training's map@1: 0.366944	valid_1's map@1: 0.278889
# [440]	training's map@1: 0.368333	valid_1's map@1: 0.276667
# Early stopping, best iteration is:
# [346]	training's map@1: 0.353889	valid_1's map@1: 0.28
# Fold 4 ------------------------------
# Training until validation scores don't improve for 100 rounds.
# [10]	training's map@1: 0.266944	valid_1's map@1: 0.226667
# [20]	training's map@1: 0.271944	valid_1's map@1: 0.225556
# [30]	training's map@1: 0.275	valid_1's map@1: 0.218889
# [40]	training's map@1: 0.275833	valid_1's map@1: 0.222222
# [50]	training's map@1: 0.279444	valid_1's map@1: 0.224444
# [60]	training's map@1: 0.282222	valid_1's map@1: 0.228889
# [70]	training's map@1: 0.286944	valid_1's map@1: 0.233333
# [80]	training's map@1: 0.287778	valid_1's map@1: 0.235556
# [90]	training's map@1: 0.293056	valid_1's map@1: 0.234444
# [100]	training's map@1: 0.296111	valid_1's map@1: 0.232222
# [110]	training's map@1: 0.298333	valid_1's map@1: 0.228889
# [120]	training's map@1: 0.302778	valid_1's map@1: 0.234444
# [130]	training's map@1: 0.305833	valid_1's map@1: 0.235556
# [140]	training's map@1: 0.310833	valid_1's map@1: 0.234444
# [150]	training's map@1: 0.3175	valid_1's map@1: 0.24
# [160]	training's map@1: 0.318889	valid_1's map@1: 0.238889
# [170]	training's map@1: 0.319444	valid_1's map@1: 0.238889
# [180]	training's map@1: 0.323611	valid_1's map@1: 0.236667
# [190]	training's map@1: 0.326667	valid_1's map@1: 0.237778
# [200]	training's map@1: 0.33	valid_1's map@1: 0.236667
# [210]	training's map@1: 0.331944	valid_1's map@1: 0.238889
# [220]	training's map@1: 0.335	valid_1's map@1: 0.238889
# [230]	training's map@1: 0.339167	valid_1's map@1: 0.241111
# [240]	training's map@1: 0.3425	valid_1's map@1: 0.238889
# [250]	training's map@1: 0.344722	valid_1's map@1: 0.238889
# [260]	training's map@1: 0.345833	valid_1's map@1: 0.24
# [270]	training's map@1: 0.348889	valid_1's map@1: 0.237778
# [280]	training's map@1: 0.350278	valid_1's map@1: 0.24
# [290]	training's map@1: 0.3525	valid_1's map@1: 0.238889
# [300]	training's map@1: 0.353611	valid_1's map@1: 0.241111
# [310]	training's map@1: 0.356944	valid_1's map@1: 0.235556
# Early stopping, best iteration is:
# [217]	training's map@1: 0.333889	valid_1's map@1: 0.242222
# mean score 0.2573333333333333

# %%
import matplotlib.pyplot as plt
import seaborn as sns

feature_importance = pd.DataFrame()
for idx,model in enumerate(models):
    fold_importance = pd.DataFrame()
    fold_importance["feature"] = ["live_city_id","desire_jd_salary_id","cur_industry_id","cur_jd_type","cur_salary_id",
             "cur_degree_id","birthday","city","jd_sub_type","require_nums",
                    "jd_sub_pos_cont","jd_sub_browsed_rate",
                    "jd_sub_delivered_rate","jd_sub_satisfied_rate",
                    "start_month",
             "max_salary","min_salary","is_travel","min_years","min_edu_level",
             "desire_jd_city_1","desire_jd_city_2","desire_jd_city_3","exp_in_desc_num",
                   "city_equal_desired_city_1","city_equal_desired_city_2","city_equal_desired_city_3",
                   "desire_min_salary","desire_max_salary","salary_large_than_desire","cur_salary_min",
                   "cur_salary_max","salary_large_than_cur","job_description_len","experience_num","work_years_statisfied","work_years","desire_jd_city_num","desire_salary_diff"]+cross_feature_names
    fold_importance["importance"] = model.feature_importances_
    fold_importance["fold"] = idx
    feature_importance = pd.concat([feature_importance,fold_importance])
plt.figure(figsize=(16, 12));
sns.barplot(x="importance", y="feature", data=feature_importance.sort_values(by="importance", ascending=False));
plt.title('satisfied LGB Features (avg over folds)');

# %%
submit = test_big_table[["user_id","jd_no"]]
submit["score"] = pred
submit = submit.reset_index(drop=True)
result = submit.groupby("user_id",as_index=False).apply(lambda x:x.sort_values("score",ascending=False))
result.head()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                                  user_id                             jd_no  \
# 0 3490  0060bfb67062ee4b1fcb276e5b3dedd2  4e706c7a2f9c2e7b15957c1264d4a96a
#   3499  0060bfb67062ee4b1fcb276e5b3dedd2  ba639f9ac20cd8e6c10be8b07538b19d
#   3481  0060bfb67062ee4b1fcb276e5b3dedd2  e6f160d3fea1cbfbf953c556dad0c75d
#   3447  0060bfb67062ee4b1fcb276e5b3dedd2  573bf456c79e9cacadfba87c032bb611
#   3456  0060bfb67062ee4b1fcb276e5b3dedd2  cdcb11f204303a8b6aae06c391a1633f
#
#            score
# 0 3490  0.158063
#   3499  0.018559
#   3481  0.011476
#   3447  0.003457
#   3456  0.001695

# %%
result[["user_id","jd_no"]].to_csv("submission1.csv",index=False)
