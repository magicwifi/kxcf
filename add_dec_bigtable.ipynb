# %%
# coding:utf-8
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split


# %matplotlib inline

# %%
train_big_table = pd.read_csv('train_big_table.csv',encoding='utf-8',index_col = False, delimiter='\t')
test_big_table = pd.read_csv('test_big_table.csv',encoding='utf-8',index_col = False, delimiter='\t')
test_big_table.drop_duplicates(inplace=True)
train_big_table.drop_duplicates(inplace=True)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (13,25,26,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (9,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
jd_sub_action_series = train_big_table.groupby(['jd_sub_type'])['browsed'].count()
jd_sub_action =pd.DataFrame({'jd_sub_type':jd_sub_action_series.index, 'jd_sub_pos_cont':jd_sub_action_series.values})
jd_sub_action['jd_sub_browsed_rate'] = train_big_table.groupby(['jd_sub_type'])['browsed'].mean().values
jd_sub_action['jd_sub_delivered_rate'] = train_big_table.groupby(['jd_sub_type'])['delivered'].mean().values
jd_sub_action['jd_sub_satisfied_rate'] = train_big_table.groupby(['jd_sub_type'])['satisfied'].mean().values
jd_sub_action['jd_sub_satisfied_cont'] = train_big_table.groupby(['jd_sub_type'])['satisfied'].sum().values
jd_sub_action['jd_sub_delivered_cont'] = train_big_table.groupby(['jd_sub_type'])['delivered'].sum().values
jd_sub_action['jd_sub_browsed_cont'] = train_big_table.groupby(['jd_sub_type'])['browsed'].sum().values
jd_sub_action['jd_sub_satisfied_conv_rate'] = jd_sub_action['jd_sub_satisfied_cont'] / jd_sub_action['jd_sub_delivered_cont']
jd_sub_action['jd_sub_delivered_conv_rate'] = jd_sub_action['jd_sub_delivered_cont'] / jd_sub_action['jd_sub_browsed_cont']
jd_sub_action.loc[jd_sub_action['jd_sub_satisfied_conv_rate'].isnull(),'jd_sub_satisfied_conv_rate']=0
jd_sub_action.loc[jd_sub_action['jd_sub_delivered_conv_rate'].isnull(),'jd_sub_delivered_conv_rate']=0
train_big_table = pd.merge(train_big_table,jd_sub_action,how="left",on="jd_sub_type")
test_big_table = pd.merge(test_big_table,jd_sub_action,how="left",on="jd_sub_type")

# %%
test_big_table.loc[test_big_table['jd_sub_type']=='办事处首席代表',['jd_sub_pos_cont','jd_sub_browsed_rate','jd_sub_delivered_rate','jd_sub_satisfied_rate','jd_sub_satisfied_conv_rate','jd_sub_delivered_conv_rate']] = 460,0.295652,0.134783,0.036957,0.274194,0.455882
test_big_table.loc[test_big_table['jd_sub_type']=='装订工',['jd_sub_pos_cont','jd_sub_browsed_rate','jd_sub_delivered_rate','jd_sub_satisfied_rate','jd_sub_satisfied_conv_rate','jd_sub_delivered_conv_rate']] = 9,0.333333,0.000000,0.000000,0.000000,0.500000
test_big_table.loc[test_big_table['jd_sub_type']=='拍卖师',['jd_sub_pos_cont','jd_sub_browsed_rate','jd_sub_delivered_rate','jd_sub_satisfied_rate','jd_sub_satisfied_conv_rate','jd_sub_delivered_conv_rate']] = 169,0.218935,0.094675,0.03550,0.375000,0.432432
test_big_table[test_big_table['jd_sub_pos_cont'].isnull()]
# Out:
# Empty DataFrame
# Columns: [user_id, jd_no, live_city_id, desire_jd_city_id, desire_jd_industry_id, desire_jd_type_id, desire_jd_salary_id, cur_industry_id, cur_jd_type, cur_salary_id, cur_degree_id, birthday, start_work_date, experience, jd_title, company_name, city, jd_sub_type, require_nums, max_salary, min_salary, start_date, end_date, is_travel, min_years, key, min_edu_level, max_edu_level, is_mangerial, resume_language_required, job_description, desire_jd_city_1, desire_jd_city_2, desire_jd_city_3, desire_jd_city_num, city_equal_desired_city_1, city_equal_desired_city_2, city_equal_desired_city_3, work_years, desire_min_salary, desire_max_salary, desire_salary_diff, work_years_statisfied, salary_large_than_desire, cur_salary_min, cur_salary_max, salary_large_than_cur, job_description_len, experience_num, exp_in_desc_num, live_city_id&city, live_city_id&desire_jd_city_1, cur_industry_id&jd_sub_type, cur_jd_type&jd_sub_type, cur_salary_id&cur_degree_id, city&jd_sub_type, jd_sub_type&min_salary, jd_sub_type&max_salary, jd_sub_type&is_travel, min_years&jd_sub_type, jd_sub_type&require_nums, jd_match_num, jd_match_title, jd_match_dec, jd_match_exp, jd_sub_pos_cont, jd_sub_browsed_rate, jd_sub_delivered_rate, jd_sub_satisfied_rate, jd_sub_satisfied_cont, jd_sub_delivered_cont, jd_sub_browsed_cont, jd_sub_satisfied_conv_rate, jd_sub_delivered_conv_rate]
# Index: []
#
# [0 rows x 74 columns]

# %%
cur_jd_action_series = train_big_table.groupby(['cur_jd_type'])['browsed'].count()
cur_jd_action =pd.DataFrame({'cur_jd_type':cur_jd_action_series.index, 'cur_jd_pos_cont':cur_jd_action_series.values})
cur_jd_action['cur_jd_browsed_rate'] = train_big_table.groupby(['cur_jd_type'])['browsed'].mean().values
cur_jd_action['cur_jd_delivered_rate'] = train_big_table.groupby(['cur_jd_type'])['delivered'].mean().values
cur_jd_action['cur_jd_satisfied_rate'] = train_big_table.groupby(['cur_jd_type'])['satisfied'].mean().values
cur_jd_action['cur_jd_satisfied_cont'] = train_big_table.groupby(['cur_jd_type'])['satisfied'].sum().values
cur_jd_action['cur_jd_delivered_cont'] = train_big_table.groupby(['cur_jd_type'])['delivered'].sum().values
cur_jd_action['cur_jd_browsed_cont'] = train_big_table.groupby(['cur_jd_type'])['browsed'].sum().values
cur_jd_action['cur_jd_satisfied_conv_rate'] = cur_jd_action['cur_jd_satisfied_cont'] / cur_jd_action['cur_jd_delivered_cont']
cur_jd_action['cur_jd_delivered_conv_rate'] = cur_jd_action['cur_jd_delivered_cont'] / cur_jd_action['cur_jd_browsed_cont']

cur_jd_action.loc[cur_jd_action['cur_jd_satisfied_conv_rate'].isnull(),'cur_jd_satisfied_conv_rate']=0
cur_jd_action.loc[cur_jd_action['cur_jd_delivered_conv_rate'].isnull(),'cur_jd_delivered_conv_rate']=0

test_big_table = pd.merge(test_big_table,cur_jd_action,how="left",on="cur_jd_type")
train_big_table = pd.merge(train_big_table,cur_jd_action,how="left",on="cur_jd_type")

# %%
test_big_table.loc[test_big_table['cur_jd_type']=='人力资源经理',['cur_jd_pos_cont','cur_jd_browsed_rate','cur_jd_delivered_rate','cur_jd_satisfied_rate','jd_sub_satisfied_conv_rate','jd_sub_delivered_conv_rate']] = 20275,0.276893,0.131591,0.051837,0.507463,0.443709
702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 45              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 46              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 47              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 48              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 49              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 50              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 51              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 52              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 53              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 54              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 55              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 56              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 58              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 59              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 60              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 61              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 62              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 63              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 64              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 65              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 66              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 67              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 68              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 69              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 70              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 71              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 72              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# 73              702           702,-,-  医药/生物工程,房地产/建筑/建材/工程              销售代表
# ...             ...               ...                   ...               ...
# 25086           538           538,-,-          房地产/建筑/建材/工程             采购/贸易
# 25087           538           538,-,-          房地产/建筑/建材/工程             采购/贸易
# 25088           538           538,-,-          房地产/建筑/建材/工程             采购/贸易
# 25089           538           538,-,-          房地产/建筑/建材/工程             采购/贸易
# 25090           538           538,-,-          房地产/建筑/建材/工程             采购/贸易
# 25091           538           538,-,-          房地产/建筑/建材/工程             采购/贸易
# 25092           635           635,-,-          房地产/建筑/建材/工程                其他
# 25093           635           635,-,-          房地产/建筑/建材/工程                其他
# 25094           635           635,-,-          房地产/建筑/建材/工程                其他
# 25095           635           635,-,-          房地产/建筑/建材/工程                其他
# 25096           635           635,-,-          房地产/建筑/建材/工程                其他
# 25097           635           635,-,-          房地产/建筑/建材/工程                其他
# 25098           635           635,-,-          房地产/建筑/建材/工程                其他
# 25099           635           635,-,-          房地产/建筑/建材/工程                其他
# 25100           635           635,-,-          房地产/建筑/建材/工程                其他
# 25101           635           635,-,-          房地产/建筑/建材/工程                其他
# 25102           635           635,-,-          房地产/建筑/建材/工程                其他
# 25103           635           635,-,-          房地产/建筑/建材/工程                其他
# 25104           635           635,-,-          房地产/建筑/建材/工程                其他
# 25105           635           635,-,-          房地产/建筑/建材/工程                其他
# 25106           635           635,-,-          房地产/建筑/建材/工程                其他
# 25107           635           635,-,-          房地产/建筑/建材/工程                其他
# 25108           635           635,-,-          房地产/建筑/建材/工程                其他
# 25109           635           635,-,-          房地产/建筑/建材/工程                其他
# 25110           635           635,-,-          房地产/建筑/建材/工程                其他
# 25111           635           635,-,-          房地产/建筑/建材/工程                其他
# 25112           635           635,-,-          房地产/建筑/建材/工程                其他
# 25113           635           635,-,-          房地产/建筑/建材/工程                其他
# 25114           635           635,-,-          房地产/建筑/建材/工程                其他
# 25115           635           635,-,-          房地产/建筑/建材/工程                其他
#
#        desire_jd_salary_id     cur_industry_id cur_jd_type cur_salary_id  ...  \
# 21               600108000  快速消费品（食品/饮料/烟酒/日化）         NaN    1000115000  ...
# 44               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 45               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 46               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 47               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 48               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 49               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 50               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 51               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 52               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 53               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 54               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 55               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 56               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 58               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 59               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 60               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 61               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 62               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 63               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 64               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 65               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 66               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 67               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 68               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 69               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 70               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 71               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 72               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# 73               400106000        房地产/建筑/建材/工程         NaN    0400106000  ...
# ...                    ...                 ...         ...           ...  ...
# 25086            800110000        房地产/建筑/建材/工程         NaN     600108000  ...
# 25087            800110000        房地产/建筑/建材/工程         NaN     600108000  ...
# 25088            800110000        房地产/建筑/建材/工程         NaN     600108000  ...
# 25089            800110000        房地产/建筑/建材/工程         NaN     600108000  ...
# 25090            800110000        房地产/建筑/建材/工程         NaN     600108000  ...
# 25091            800110000        房地产/建筑/建材/工程         NaN     600108000  ...
# 25092            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25093            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25094            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25095            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25096            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25097            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25098            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25099            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25100            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25101            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25102            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25103            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25104            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25105            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25106            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25107            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25108            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25109            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25110            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25111            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25112            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25113            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25114            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
# 25115            600108000        房地产/建筑/建材/工程         NaN     400106000  ...
#
#        jd_sub_delivered_conv_rate  cur_jd_pos_cont cur_jd_browsed_rate  \
# 21                       0.455524              NaN                 NaN
# 44                       0.450174              NaN                 NaN
# 45                       0.448904              NaN                 NaN
# 46                       0.489862              NaN                 NaN
# 47                       0.416667              NaN                 NaN
# 48                       0.406504              NaN                 NaN
# 49                       0.390311              NaN                 NaN
# 50                       0.344334              NaN                 NaN
# 51                       0.489862              NaN                 NaN
# 52                       0.406504              NaN                 NaN
# 53                       0.489862              NaN                 NaN
# 54                       0.406504              NaN                 NaN
# 55                       0.469512              NaN                 NaN
# 56                       0.455524              NaN                 NaN
# 58                       0.477528              NaN                 NaN
# 59                       0.406504              NaN                 NaN
# 60                       0.406504              NaN                 NaN
# 61                       0.406504              NaN                 NaN
# 62                       0.416667              NaN                 NaN
# 63                       0.390311              NaN                 NaN
# 64                       0.385356              NaN                 NaN
# 65                       0.489862              NaN                 NaN
# 66                       0.406504              NaN                 NaN
# 67                       0.489862              NaN                 NaN
# 68                       0.416667              NaN                 NaN
# 69                       0.390311              NaN                 NaN
# 70                       0.416667              NaN                 NaN
# 71                       0.406504              NaN                 NaN
# 72                       0.406504              NaN                 NaN
# 73                       0.390311              NaN                 NaN
# ...                           ...              ...                 ...
# 25086                    0.506745              NaN                 NaN
# 25087                    0.528017              NaN                 NaN
# 25088                    0.506745              NaN                 NaN
# 25089                    0.460705              NaN                 NaN
# 25090                    0.528017              NaN                 NaN
# 25091                    0.460705              NaN                 NaN
# 25092                    0.489862              NaN                 NaN
# 25093                    0.448904              NaN                 NaN
# 25094                    0.450174              NaN                 NaN
# 25095                    0.504212              NaN                 NaN
# 25096                    0.401239              NaN                 NaN
# 25097                    0.401239              NaN                 NaN
# 25098                    0.450174              NaN                 NaN
# 25099                    0.450174              NaN                 NaN
# 25100                    0.401239              NaN                 NaN
# 25101                    0.517483              NaN                 NaN
# 25102                    0.432554              NaN                 NaN
# 25103                    0.401239              NaN                 NaN
# 25104                    0.504212              NaN                 NaN
# 25105                    0.489862              NaN                 NaN
# 25106                    0.489862              NaN                 NaN
# 25107                    0.469512              NaN                 NaN
# 25108                    0.489862              NaN                 NaN
# 25109                    0.401239              NaN                 NaN
# 25110                    0.469974              NaN                 NaN
# 25111                    0.401239              NaN                 NaN
# 25112                    0.401239              NaN                 NaN
# 25113                    0.401239              NaN                 NaN
# 25114                    0.489862              NaN                 NaN
# 25115                    0.545455              NaN                 NaN
#
#       cur_jd_delivered_rate cur_jd_satisfied_rate cur_jd_satisfied_cont  \
# 21                      NaN                   NaN                   NaN
# 44                      NaN                   NaN                   NaN
# 45                      NaN                   NaN                   NaN
# 46                      NaN                   NaN                   NaN
# 47                      NaN                   NaN                   NaN
# 48                      NaN                   NaN                   NaN
# 49                      NaN                   NaN                   NaN
# 50                      NaN                   NaN                   NaN
# 51                      NaN                   NaN                   NaN
# 71                       NaN                 NaN                         NaN
# 72                       NaN                 NaN                         NaN
# 73                       NaN                 NaN                         NaN
# ...                      ...                 ...                         ...
# 25086                    NaN                 NaN                         NaN
# 25087                    NaN                 NaN                         NaN
# 25088                    NaN                 NaN                         NaN
# 25089                    NaN                 NaN                         NaN
# 25090                    NaN                 NaN                         NaN
# 25091                    NaN                 NaN                         NaN
# 25092                    NaN                 NaN                         NaN
# 25093                    NaN                 NaN                         NaN
# 25094                    NaN                 NaN                         NaN
# 25095                    NaN                 NaN                         NaN
# 25096                    NaN                 NaN                         NaN
# 25097                    NaN                 NaN                         NaN
# 25098                    NaN                 NaN                         NaN
# 25099                    NaN                 NaN                         NaN
# 25100                    NaN                 NaN                         NaN
# 25101                    NaN                 NaN                         NaN
# 25102                    NaN                 NaN                         NaN
# 25103                    NaN                 NaN                         NaN
# 25104                    NaN                 NaN                         NaN
# 25105                    NaN                 NaN                         NaN
# 25106                    NaN                 NaN                         NaN
# 25107                    NaN                 NaN                         NaN
# 25108                    NaN                 NaN                         NaN
# 25109                    NaN                 NaN                         NaN
# 25110                    NaN                 NaN                         NaN
# 25111                    NaN                 NaN                         NaN
# 25112                    NaN                 NaN                         NaN
# 25113                    NaN                 NaN                         NaN
# 25114                    NaN                 NaN                         NaN
# 25115                    NaN                 NaN                         NaN
#
#        cur_jd_delivered_conv_rate
# 21                            NaN
# 44                            NaN
# 45                            NaN
# 46                            NaN
# 47                            NaN
# 48                            NaN
# 49                            NaN
# 50                            NaN
# 51                            NaN
# 52                            NaN
# 53                            NaN
# 54                            NaN
# 55                            NaN
# 56                            NaN
# 58                            NaN
# 59                            NaN
# 60                            NaN
# 61                            NaN
# 62                            NaN
# 63                            NaN
# 64                            NaN
# 65                            NaN
# 66                            NaN
# 67                            NaN
# 68                            NaN
# 69                            NaN
# 70                            NaN
# 71                            NaN
# 72                            NaN
# 73                            NaN
# ...                           ...
# 25086                         NaN
# 25087                         NaN
# 25088                         NaN
# 25089                         NaN
# 25090                         NaN
# 25091                         NaN
# 25092                         NaN
# 25093                         NaN
# 25094                         NaN
# 25095                         NaN
# 25096                         NaN
# 25097                         NaN
# 25098                         NaN
# 25099                         NaN
# 25100                         NaN
# 25101                         NaN
# 25102                         NaN
# 25103                         NaN
# 25104                         NaN
# 25105                         NaN
# 25106                         NaN
# 25107                         NaN
# 25108                         NaN
# 25109                         NaN
# 25110                         NaN
# 25111                         NaN
# 25112                         NaN
# 25113                         NaN
# 25114                         NaN
# 25115                         NaN
#
# [8745 rows x 83 columns]

# %%
train_big_table['start_date'].fillna('na',inplace=True)
test_big_table['start_date'].fillna('na',inplace=True)
train_big_table['end_date'].fillna('na',inplace=True)
test_big_table['end_date'].fillna('na',inplace=True)
train_big_table['start_date'] = train_big_table['start_date'].astype(str)
train_big_table['end_date'] = train_big_table['end_date'].astype(str)
test_big_table['start_date'] = test_big_table['start_date'].astype(str)
test_big_table['end_date'] = test_big_table['end_date'].astype(str)

# %%
from datetime import datetime

def remain_date(x):
    if  'N' in x :
        return 99999;
    elif 'na' in x:
        return -1
    else:
        d1 = datetime.strptime('20190327', "%Y%m%d")
        d2 = datetime.strptime(x, "%Y%m%d")
        return abs((d2 - d1).days)
    
train_big_table['remain_date'] = train_big_table['end_date'].apply(remain_date)
test_big_table['remain_date'] = test_big_table['end_date'].apply(remain_date)

# %%
def month_convert(x):
    if  'N' in x:
        return -1;
    elif 'na' in x:
        return -1
    else:
        if int(x[0:6])< 201804:
            return '201804'
        else:
            return x[0:6]

train_big_table['start_month'] = train_big_table['start_date'].apply(month_convert)
test_big_table['start_month'] = test_big_table['start_date'].apply(month_convert)

# %%
cross_feature_names = ['live_city_id&city', 'live_city_id&desire_jd_city_1', 'cur_industry_id&jd_sub_type', 'cur_jd_type&jd_sub_type', 'cur_salary_id&cur_degree_id', 'city&jd_sub_type', 'jd_sub_type&min_salary', 'jd_sub_type&max_salary', 'jd_sub_type&is_travel', 'min_years&jd_sub_type', 'jd_sub_type&require_nums']

# %%
all_big_table = pd.concat([train_big_table,test_big_table])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if __name__ == '__main__':

# %%
from sklearn.preprocessing import LabelEncoder
from tqdm import tqdm as tqdm
import lightgbm as lgb

# %%
def feature_select(target,*df_list):
    result = []
    cat_features = ["live_city_id","desire_jd_salary_id","cur_industry_id","cur_jd_type","cur_salary_id",
         "cur_degree_id","city","jd_sub_type","start_month",
         "max_salary","min_salary","is_travel","min_years","min_edu_level",
         "desire_jd_city_1","desire_jd_city_2","desire_jd_city_3","work_years_statisfied"]+cross_feature_names
    lbl_dict = {}
    for f in cat_features:
        lbl = LabelEncoder()
        lbl.fit(all_big_table[f].astype(str))
        lbl_dict[f] = lbl
    for df in df_list:
        features = ["live_city_id","desire_jd_salary_id","cur_industry_id","cur_jd_type","cur_salary_id",
             "cur_degree_id","birthday","city","jd_sub_type","require_nums","cur_jd_browsed_rate",
                    "cur_jd_delivered_rate","cur_jd_satisfied_rate",
                    "jd_sub_browsed_rate",
                    "jd_sub_delivered_rate","jd_sub_satisfied_rate",
                    "start_month",
             "max_salary","min_salary","is_travel","min_years","min_edu_level",
             "desire_jd_city_1","desire_jd_city_2","desire_jd_city_3","exp_in_desc_num",
                   "desire_min_salary","desire_max_salary","salary_large_than_desire","cur_salary_min",
                   "cur_salary_max","salary_large_than_cur","job_description_len","experience_num","work_years_statisfied","work_years","desire_jd_city_num","desire_salary_diff"]+cross_feature_names

        x = df[features]
        if target in df.columns:
            y = df[target]
        else:
            y = None
        for f in cat_features:
            lbl = lbl_dict[f]
            x[f] = lbl.transform(x[f].astype(str))
        result.append((x,y))
    return result

# %%
from sklearn.model_selection import KFold

def cross_validate(param=dict(n_estimators=1000,metric="map",colsample_bytree=0.2,max_depth=7,importance_type="gain",device="gpu",gpu_platform_id=0,gpu_device_id=0)
                   ,n_folds=5,target="mix_sat"):
    train_users = train_big_table["user_id"].unique()
    folds = KFold(n_folds,shuffle=True,random_state=42)
    models = []
    test_pred = np.zeros(test_big_table.shape[0])
    scores = []
    for idx,(train_idx,valid_idx) in enumerate(folds.split(train_users)):
        t_user = train_users[train_idx]
        v_user = train_users[valid_idx]
        train_data = train_big_table[train_big_table["user_id"].isin(t_user)]
        valid_data = train_big_table[train_big_table["user_id"].isin(v_user)]
        train_group = train_data.groupby("user_id",as_index=False).count()["mix_sat"].values
        valid_group = valid_data.groupby("user_id",as_index=False).count()["mix_sat"].values
        test_group = test_big_table.groupby("user_id",as_index=False).count()["jd_no"].values
        
        result = feature_select(target,train_data,valid_data,test_big_table)
        t_x,t_y = result[0]
        v_x,v_y = result[1]
        test_x,_ = result[2]
        model = lgb.LGBMRanker(**param)
        print("Fold",idx,"-"*30)
        model.fit(t_x,t_y,group=train_group,eval_set=[(t_x,t_y),(v_x,v_y)],eval_group=[train_group,valid_group],early_stopping_rounds=100,verbose=10,
                  callbacks=[lgb.reset_parameter(learning_rate=lambda x: 0.03)]
                 )
        models.append(model)
        test_pred += model.predict(test_x)/n_folds
        scores.append(model.best_score_["valid_1"]["map@1"])
    print("mean score",np.mean(scores))
    return models,test_pred

# %%
test_big_table.shape
# Out:
# (25116, 85)

# %%
models,pred = cross_validate(target="mix_sat",param=dict(n_estimators=1000,metric="map",subsample=0.6,min_split_gain=10,colsample_bytree=0.6,max_depth=7,importance_type="gain",device="gpu",gpu_platform_id=0,gpu_device_id=0),n_folds=5)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Fold 0 ------------------------------
# Training until validation scores don't improve for 100 rounds.
# [10]	training's map@1: 0.252781	valid_1's map@1: 0.242492
# [20]	training's map@1: 0.270022	valid_1's map@1: 0.224694
# [30]	training's map@1: 0.275584	valid_1's map@1: 0.226919
# [40]	training's map@1: 0.28059	valid_1's map@1: 0.225806
# [50]	training's map@1: 0.283648	valid_1's map@1: 0.234705
# [60]	training's map@1: 0.289766	valid_1's map@1: 0.235818
# [70]	training's map@1: 0.293938	valid_1's map@1: 0.230256
# [80]	training's map@1: 0.300334	valid_1's map@1: 0.23693
# [90]	training's map@1: 0.30812	valid_1's map@1: 0.234705
# [100]	training's map@1: 0.310623	valid_1's map@1: 0.23693
# Early stopping, best iteration is:
# [9]	training's map@1: 0.253893	valid_1's map@1: 0.248053
# Fold 1 ------------------------------
# Training until validation scores don't improve for 100 rounds.
# [10]	training's map@1: 0.247219	valid_1's map@1: 0.20356
# [20]	training's map@1: 0.263904	valid_1's map@1: 0.211346
# [30]	training's map@1: 0.271135	valid_1's map@1: 0.209121
# [40]	training's map@1: 0.278921	valid_1's map@1: 0.216908
# [50]	training's map@1: 0.285873	valid_1's map@1: 0.215795
# [60]	training's map@1: 0.291157	valid_1's map@1: 0.206897
# [70]	training's map@1: 0.299221	valid_1's map@1: 0.210234
# [80]	training's map@1: 0.300612	valid_1's map@1: 0.211346
# [90]	training's map@1: 0.306452	valid_1's map@1: 0.213571
# [100]	training's map@1: 0.308676	valid_1's map@1: 0.213571
# Early stopping, best iteration is:
# [4]	training's map@1: 0.235261	valid_1's map@1: 0.219132
# Fold 2 ------------------------------
# Training until validation scores don't improve for 100 rounds.
# [10]	training's map@1: 0.255006	valid_1's map@1: 0.222469
# [20]	training's map@1: 0.271135	valid_1's map@1: 0.231368
# [30]	training's map@1: 0.279755	valid_1's map@1: 0.231368
# [40]	training's map@1: 0.288654	valid_1's map@1: 0.232481
# [50]	training's map@1: 0.286986	valid_1's map@1: 0.233593
# [60]	training's map@1: 0.292269	valid_1's map@1: 0.226919
# [70]	training's map@1: 0.295328	valid_1's map@1: 0.234705
# [80]	training's map@1: 0.30228	valid_1's map@1: 0.230256
# [90]	training's map@1: 0.305339	valid_1's map@1: 0.230256
# [100]	training's map@1: 0.308676	valid_1's map@1: 0.234705
# [110]	training's map@1: 0.316185	valid_1's map@1: 0.234705
# [120]	training's map@1: 0.316185	valid_1's map@1: 0.232481
# Early stopping, best iteration is:
# [25]	training's map@1: 0.271135	valid_1's map@1: 0.241379
# Fold 3 ------------------------------
# Training until validation scores don't improve for 100 rounds.
# [10]	training's map@1: 0.248331	valid_1's map@1: 0.222469
# [20]	training's map@1: 0.266963	valid_1's map@1: 0.230256
# [30]	training's map@1: 0.273915	valid_1's map@1: 0.234705
# [40]	training's map@1: 0.28337	valid_1's map@1: 0.246941
# [50]	training's map@1: 0.285317	valid_1's map@1: 0.25139
# [60]	training's map@1: 0.289766	valid_1's map@1: 0.253615
# [70]	training's map@1: 0.293103	valid_1's map@1: 0.254727
# [80]	training's map@1: 0.295606	valid_1's map@1: 0.256952
# [90]	training's map@1: 0.297553	valid_1's map@1: 0.259177
# [100]	training's map@1: 0.30228	valid_1's map@1: 0.253615
# [110]	training's map@1: 0.303949	valid_1's map@1: 0.256952
# [120]	training's map@1: 0.306452	valid_1's map@1: 0.252503
# [130]	training's map@1: 0.311179	valid_1's map@1: 0.249166
# [140]	training's map@1: 0.31396	valid_1's map@1: 0.25584
# [150]	training's map@1: 0.317297	valid_1's map@1: 0.25139
# [160]	training's map@1: 0.322859	valid_1's map@1: 0.254727
# [170]	training's map@1: 0.32703	valid_1's map@1: 0.25139
# [180]	training's map@1: 0.329255	valid_1's map@1: 0.250278
# [190]	training's map@1: 0.33287	valid_1's map@1: 0.252503
# [200]	training's map@1: 0.334816	valid_1's map@1: 0.253615
# [210]	training's map@1: 0.33871	valid_1's map@1: 0.250278
# Early stopping, best iteration is:
# [112]	training's map@1: 0.303393	valid_1's map@1: 0.261402
# Fold 4 ------------------------------
# Training until validation scores don't improve for 100 rounds.
# [10]	training's map@1: 0.260567	valid_1's map@1: 0.208009
# [20]	training's map@1: 0.268076	valid_1's map@1: 0.20356
# [30]	training's map@1: 0.27475	valid_1's map@1: 0.211346
# [40]	training's map@1: 0.278087	valid_1's map@1: 0.211346
# [50]	training's map@1: 0.284205	valid_1's map@1: 0.210234
# [60]	training's map@1: 0.28921	valid_1's map@1: 0.208009
# [70]	training's map@1: 0.290879	valid_1's map@1: 0.214683
# [80]	training's map@1: 0.29644	valid_1's map@1: 0.214683
# [90]	training's map@1: 0.299778	valid_1's map@1: 0.214683
# [100]	training's map@1: 0.305061	valid_1's map@1: 0.215795
# [110]	training's map@1: 0.30673	valid_1's map@1: 0.222469
# [120]	training's map@1: 0.30673	valid_1's map@1: 0.225806
# [130]	training's map@1: 0.309789	valid_1's map@1: 0.220245
# [140]	training's map@1: 0.316463	valid_1's map@1: 0.215795
# [150]	training's map@1: 0.318966	valid_1's map@1: 0.211346
# [160]	training's map@1: 0.324527	valid_1's map@1: 0.215795
# [170]	training's map@1: 0.326474	valid_1's map@1: 0.212458
# [180]	training's map@1: 0.330923	valid_1's map@1: 0.212458
# [190]	training's map@1: 0.335929	valid_1's map@1: 0.211346
# [200]	training's map@1: 0.341212	valid_1's map@1: 0.21802
# [210]	training's map@1: 0.342881	valid_1's map@1: 0.215795
# Early stopping, best iteration is:
# [113]	training's map@1: 0.308398	valid_1's map@1: 0.225806
# mean score 0.23915461624026696

# %%
import matplotlib.pyplot as plt
import seaborn as sns

feature_importance = pd.DataFrame()
for idx,model in enumerate(models):
    fold_importance = pd.DataFrame()
    fold_importance["feature"] = ["live_city_id","desire_jd_salary_id","cur_industry_id","cur_jd_type","cur_salary_id",
             "cur_degree_id","birthday","city","jd_sub_type","require_nums","cur_jd_browsed_rate",
                    "cur_jd_delivered_rate","cur_jd_satisfied_rate",
                    "jd_sub_browsed_rate",
                    "jd_sub_delivered_rate","jd_sub_satisfied_rate",
                    "start_month",
             "max_salary","min_salary","is_travel","min_years","min_edu_level",
             "desire_jd_city_1","desire_jd_city_2","desire_jd_city_3","exp_in_desc_num",
                   "desire_min_salary","desire_max_salary","salary_large_than_desire","cur_salary_min",
                   "cur_salary_max","salary_large_than_cur","job_description_len","experience_num","work_years_statisfied","work_years","desire_jd_city_num","desire_salary_diff"]+cross_feature_names

    fold_importance["importance"] = model.feature_importances_
    fold_importance["fold"] = idx
    feature_importance = pd.concat([feature_importance,fold_importance])
plt.figure(figsize=(16, 12));
sns.barplot(x="importance", y="feature", data=feature_importance.sort_values(by="importance", ascending=False));
plt.title('mix_satsatisfied LGB Features (avg over folds)');

# %%
test_action = pd.read_csv("data/zhaopin_round1_user_exposure_A_20190723",delim_whitespace=True)
test_action.head()
# Out:
#                             user_id                             jd_no
# 0  035b5c8e977d2f76628d9b7edfc95323  669576ca43ff7b2b6f5bc97a3dfeda9e
# 1  035b5c8e977d2f76628d9b7edfc95323  2fc7d27894fe1776e7b76546deb8ae5d
# 2  035b5c8e977d2f76628d9b7edfc95323  bd97a1c4461ac4984f4211c1c75f7f7a
# 3  035b5c8e977d2f76628d9b7edfc95323  da7b5e1d6537d2fca4595c7c1672e609
# 4  035b5c8e977d2f76628d9b7edfc95323  5bc733283200a5d7b5cf3eb45cde4db7

# %%
submit = test_big_table[["user_id","jd_no"]]
submit["score"] = pred
submit = submit.reset_index(drop=True)
result = pd.merge(test_action,submit,how="left",on=["user_id","jd_no"])
result.fillna(-100,inplace=True)
result = result.groupby("user_id",as_index=False).apply(lambda x:x.sort_values("score",ascending=False))
result[["user_id","jd_no","score"]].to_csv("submission2.csv",index=False)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
submit = test_big_table[["user_id","jd_no"]]
submit["score"] = pred
submit = submit.reset_index(drop=True)
result = pd.merge(test_action,submit,how="left",on=["user_id","jd_no"])
result.fillna(-100,inplace=True)
result = result.groupby("user_id",as_index=False).apply(lambda x:x.sort_values("score",ascending=False))
# 需要对结果进行去重
result[["user_id","jd_no","score"]].drop_duplicates().to_csv("submission2.csv",index=False)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
#work_years_statisfied=1
#is_edu_ok？ 1
#year&is_city_eq
